# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
run6482 = np.array([702452.37125492, 427906.21551372, 176084.41517146, 155196.25943807, 135682.97629837,  62954.40563619,  12084.95820488,   8750.17196923, 7672.57392861])
run6482err = np.array([778.1568408 , 152.12824575,  37.75485398, 158.02734676, 160.94895532,  50.6408593 ,  14.8707866 ,   2.8838005 , 1.22669362])

run6483 = np.array([701847.35212835, 428135.20378131, 175940.78873509, 155029.46961837, 135733.64115245,  62853.36744786,  12081.60195942,   8750.10612606, 7675.22671429])
run6483err = np.array([669.78879157, 165.45546038,  35.47888571, 178.25437153, 118.95247613,  50.65335828,  15.07822578,   2.92133025, 1.2767361 ])

run6484 = np.array([701112.95313891, 428150.38856044, 176030.61606499, 155111.83255087, 132716.6583224,  62830.88853426,  12092.83260887,   8752.39381608, 7676.67543045])
run6484err = np.array([7.82226445e+02, 1.61377371e+02, 3.73729212e+01, 1.48255574e+02, 2.77586483e+05, 4.97055017e+01, 1.45687380e+01, 2.89048611e+00, 1.25179602e+00])

run6485 = np.array([701152.74933029, 428812.28913468, 176162.62002169, 155376.17590578, 135964.27040575,  63025.60478003,  12091.07015464,   8755.24407936, 7683.55686486])
run6485err = np.array([891.92839448, 177.5533647 ,  37.50790516, 178.23097881, 131.02750431,  63.86009535,  16.46459057,   3.14867632, 1.38572879])

# %%
plt.hist((run6483-run6482)/(run6483err**2 + run6482err**2)**0.5, 100);

# %%
plt.hist((run6484-run6482)/(run6484err**2 + run6482err**2)**0.5, 100);

# %%
plt.hist((run6485-run6482)/(run6485err**2 + run6482err**2)**0.5, 100);

# %%
plt.hist((run6484-run6483)/(run6484err**2 + run6483err**2)**0.5, 100);

# %%
plt.hist((run6485-run6483)/(run6485err**2 + run6483err**2)**0.5, 100);

# %%
plt.hist((run6485-run6484)/(run6485err**2 + run6484err**2)**0.5, 100);
