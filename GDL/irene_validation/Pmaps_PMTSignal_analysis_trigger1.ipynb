# %%
import glob
import numpy             as np
import pandas            as pd
import tables            as tb
import matplotlib.pyplot as plt

from histogram_functions import *

from invisible_cities.io.pmaps_io import load_pmaps_as_df

to_df = pd.DataFrame.from_records

# %%
icversion_file  = "./pmtsignal_summary_trigger1_icversion.h5"
testprod_file   = "./pmtsignal_summary_trigger1_ictestprod.h5"
testprod_p_file = "./pmtsignal_summary_trigger1_ictestprod_p.h5"

# %% [markdown]
# ## Rates

# %%
nS_icversion  = pd.read_hdf(icversion_file , key="nS")
nS_testprod   = pd.read_hdf(testprod_file  , key="nS")
nS_testprod_p = pd.read_hdf(testprod_p_file, key="nS")


nev_icversion  = pd.read_hdf(icversion_file , key="nevent")
nev_testprod   = pd.read_hdf(testprod_file  , key="nevent")
nev_testprod_p = pd.read_hdf(testprod_p_file, key="nevent")

# %%
print("1S1 RATES")
print()
print("IC v0.9.9"    , len(nS_icversion[nS_icversion["nS1s"]==1])  , len(nS_icversion[nS_icversion["nS1s"]==1])/len(nS_icversion)*100)
print("IC testprod"  , len(nS_testprod[nS_testprod["nS1s"]==1])    , len(nS_testprod[nS_testprod["nS1s"]==1])/len(nS_testprod)*100)
print("IC testprod_p", len(nS_testprod_p[nS_testprod_p["nS1s"]==1]), len(nS_testprod_p[nS_testprod_p["nS1s"]==1])/len(nS_testprod_p)*100)
# Out:
# 1S1 RATES
#
# IC v0.9.9 7371 28.00319124686574
# IC testprod 7371 28.00319124686574
# IC testprod_p 7414 27.89525171194221

# %%
print("1S1 1S2 RATES")
print()
print("IC v0.9.9"    , len(nS_icversion[(nS_icversion["nS1s"]==1)&(nS_icversion["nS2s"]==1)])/len(nS_icversion)*100)
print("IC testprod"  , len(nS_testprod[(nS_testprod["nS1s"]==1)&(nS_testprod["nS2s"]==1)])/len(nS_testprod)*100)
print("IC testprod_p", len(nS_testprod_p[(nS_testprod_p["nS1s"]==1)&(nS_testprod_p["nS2s"]==1)])/len(nS_testprod_p)*100)
# Out:
# 1S1 1S2 RATES
#
# IC v0.9.9 25.50338120203632
# IC testprod 25.50338120203632
# IC testprod_p 25.36684475882309

# %%
key = "nevent"
histo1D(nev_icversion [key].values+0.2,
        nev_testprod  [key].values+0.5,
        nev_testprod_p[key].values,
        xlabel = "number of events by pmaps-file",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins= 1000,
        xlims=[None, None],
        scale = "linear")

# %%
key = "nS1s"
histo1D(nS_icversion [key].values,
        nS_testprod  [key].values,
        nS_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=np.arange(-0.5, 20),
        xlims=[None, 20],
        scale = "linear")

# %%
key = "nS2s"
histo1D(nS_icversion [key].values,
        nS_testprod  [key].values,
        nS_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=np.arange(-0.5, 5),
        xlims=[None, 5],
        scale = "log")

# %% [markdown]
# ## S1

# %%
S1_icversion  = pd.read_hdf(icversion_file, key="S1")
S1_testprod   = pd.read_hdf(testprod_file, key="S1")
S1_testprod_p = pd.read_hdf(testprod_p_file, key="S1")

# %%
key = "time"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100,
        Bbox=False)

# %%
key = "height"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, 100],
        scale = "log")

# %%
key = "energy"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, 4e3],
        scale = "log")

# %%
key = "width"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, None],
        scale = "linear")

# %%
key = "mactPMT"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = "Most active PMT",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=np.arange(-0.5, 12.5), 
        xlims=[None, None],
        scale = "linear")

# %%
key = "mact_perc"
histo1D(S1_icversion [key].values,
        S1_testprod  [key].values,
        S1_testprod_p[key].values,
        xlabel = "% energy most active PMT",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, 50],
        scale = "linear")

# %% [markdown]
# ## S2

# %%
S2_icversion  = pd.read_hdf(icversion_file , key="S2")
S2_testprod   = pd.read_hdf(testprod_file  , key="S2")
S2_testprod_p = pd.read_hdf(testprod_p_file, key="S2")

# %%
key = "time"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100,
        xlims = [700, 1200],
        scale="log")

# %%
key = "height"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p [S2_testprod_p["time"].values>=795][key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, None],
        scale = "log")

# %%
key = "energy"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p[S2_testprod_p["time"].values>=795][key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, 4e5],
        scale = "log")

# %%
key = "width"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p[key].values,
        xlabel = key,
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=1000, 
        xlims=[None, 3e4],
        scale = "log")

# %%
np.mean(S2_testprod_p [S2_testprod_p["time"].values>=795][key].values)
# Out:
# 11197.691408240209

# %%
np.mean(S2_testprod [key].values)
# Out:
# 9848.98228470077

# %%
np.mean(S2_icversion [key].values)
# Out:
# 9848.98228470077

# %%
key = "mactPMT"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p [S2_testprod_p["time"]>=795][key].values,
        xlabel = "Most active PMT",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=np.arange(-0.5, 12.5), 
        xlims=[-0.5, None],
        scale = "linear")

# %%
key = "mact_perc"
histo1D(S2_icversion [key].values,
        S2_testprod  [key].values,
        S2_testprod_p[key].values,
        xlabel = "% energy most active PMT",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins=100, 
        xlims=[None, 15],
        scale = "linear")
