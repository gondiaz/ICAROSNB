# %%
import glob
import numpy             as np
import pandas            as pd
import tables            as tb
import matplotlib.pyplot as plt

from histogram_functions import *

from invisible_cities.io.pmaps_io import load_pmaps_as_df

to_df = pd.DataFrame.from_records

# %%
icversion_file  = "./sisignal_summary_trigger2_icversion.h5"
testprod_file   = "./sisignal_summary_trigger2_ictestprod.h5"
testprod_p_file = "./sisignal_summary_trigger2_ictestprod_p.h5"

# %%
Q_icversion  = pd.read_hdf(icversion_file , key="Q")
Q_testprod   = pd.read_hdf(testprod_file  , key="Q")
Q_testprod_p = pd.read_hdf(testprod_p_file, key="Q")


qsl_icversion  = pd.read_hdf(icversion_file , key="sl")
qsl_testprod   = pd.read_hdf(testprod_file  , key="sl")
qsl_testprod_p = pd.read_hdf(testprod_p_file, key="sl")

# %%
key = "charge"
histo1D(Q_icversion [key].values,
        Q_testprod  [key].values,
        Q_testprod_p[key].values,
        xlabel = "total Q",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins= 1000,
        xlims=[None, 2e4],
        scale = "linear")

# %%
key = "touch"
histo1D(Q_icversion [key].values,
        Q_testprod  [key].values,
        Q_testprod_p[key].values,
        xlabel = "Number of SiPMs touched",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins= 1000,
        xlims=[None, None],
        scale = "linear")

# %%
key = "charge_per_sl"
histo1D(qsl_icversion [key].values,
        qsl_testprod  [key].values,
        qsl_testprod_p[key].values,
        xlabel = "charge per slide",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins= 1000,
        xlims=[None, None],
        scale = "log")

# %%
key = "charge_per_sl"
histo1D(qsl_icversion [key].values,
        qsl_testprod  [key].values,
        qsl_testprod_p[key].values,
        xlabel = "charge per slide",
        Label0 = "icversion",
        Label1 = "testprod",
        Label2 = "testprod-p",
        bins= 1000,
        xlims=[None, 2.5],
        scale = "log")
